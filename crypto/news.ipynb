# %%
import sqlite3
import pandas
from crypto_news import *
import header
from pymongo import MongoClient
import webbrowser

# %%
news = NewsSentiment()
items,info = news.news()

# %%
news.filter_sentiments(info,'Somewhat-Bullish')
# url = news.filter_sentiments(info,'Somewhat-Bullish').url
# webbrowser.open(url[11])
# Out:
#                                                 title  \
# 11  Tesla Accepting Bitcoin Inspired This Major Co...
# 20  Crypto Corner Podcast: Cryptocurrency Stocks i...
# 23  Crypto Went Crazy Over Coinbase's Blockchain P...
# 47  Will Crypto Recover to Previous Highs, or Will...
# 48  Coinbase Pushes Pro-Crypto Campaign To Counter...
#
#                                                   url   time_published  \
# 11  https://www.benzinga.com/markets/cryptocurrenc...  20230304T221443
# 20  https://www.investorideas.com/news/2023/crypto...  20230303T184232
# 23  https://www.barrons.com/articles/coinbase-cryp...  20230303T154800
# 47  https://www.fool.com/investing/2023/03/01/will...  20230301T122500
# 48  https://www.benzinga.com/markets/cryptocurrenc...  20230301T112023
#
#               authors                                            summary  \
# 11      [Chris Katje]  Many major companies have launched plans or ex...
# 20                 []  Crypto Corner Podcast: Cryptocurrency Stocks i...
# 23      [Jack Denton]  Crypto Went Crazy Over Coinbase's Blockchain P...
# 47  [Dominic Basulto]  There are four key factors that could determin...
# 48    [Mehab Qureshi]  Coinbase COIN on Tuesday launched #Crypto435, ...
#
#                                          banner_image          source  \
# 11  https://cdn.benzinga.com/files/images/story/20...        Benzinga
# 20                                               None  Investor Ideas
# 23        https://images.barrons.com/im-324835/social         Barrons
# 47  https://g.foolcdn.com/image/?url=https%3A%2F%2...     Motley Fool
# 48  https://cdn.benzinga.com/files/images/story/20...        Benzinga
#
#    category_within_source          source_domain  \
# 11                Markets       www.benzinga.com
# 20                    n/a  www.investorideas.com
# 23                    n/a        www.barrons.com
# 47                    n/a           www.fool.com
# 48                Markets       www.benzinga.com
#
#                                                topics  \
# 11  [{'topic': 'Finance', 'relevance_score': '0.5'...
# 20  [{'topic': 'Life Sciences', 'relevance_score':...
# 23  [{'topic': 'Finance', 'relevance_score': '1.0'...
# 47  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 48  [{'topic': 'Finance', 'relevance_score': '1.0'...
#
#     overall_sentiment_score overall_sentiment_label  \
# 11                 0.213459        Somewhat-Bullish
# 20                 0.268336        Somewhat-Bullish
# 23                 0.298702        Somewhat-Bullish
# 47                 0.236590        Somewhat-Bullish
# 48                 0.257247        Somewhat-Bullish
#
#                                      ticker_sentiment
# 11  [{'ticker': 'COIN', 'relevance_score': '0.1554...
# 20  [{'ticker': 'GOOG', 'relevance_score': '0.0557...
# 23  [{'ticker': 'COIN', 'relevance_score': '0.9135...
# 47  [{'ticker': 'BLK', 'relevance_score': '0.16655...
# 48  [{'ticker': 'COIN', 'relevance_score': '0.5671...

# %%
news = NewsSentiment()
items,info = news.news()
data = news.filter_sentiments(info,'Somewhat-Bullish')
print(data)
# news.save_to_database(data)
# Out:
#                                                 title  \
# 11  Tesla Accepting Bitcoin Inspired This Major Co...
# 20  Crypto Corner Podcast: Cryptocurrency Stocks i...
# 23  Crypto Went Crazy Over Coinbase's Blockchain P...
# 47  Will Crypto Recover to Previous Highs, or Will...
# 48  Coinbase Pushes Pro-Crypto Campaign To Counter...
#
#                                                   url   time_published  \
# 11  https://www.benzinga.com/markets/cryptocurrenc...  20230304T221443
# 20  https://www.investorideas.com/news/2023/crypto...  20230303T184232
# 23  https://www.barrons.com/articles/coinbase-cryp...  20230303T154800
# 47  https://www.fool.com/investing/2023/03/01/will...  20230301T122500
# 48  https://www.benzinga.com/markets/cryptocurrenc...  20230301T112023
#
#               authors                                            summary  \
# 11      [Chris Katje]  Many major companies have launched plans or ex...
# 20                 []  Crypto Corner Podcast: Cryptocurrency Stocks i...
# 23      [Jack Denton]  Crypto Went Crazy Over Coinbase's Blockchain P...
# 47  [Dominic Basulto]  There are four key factors that could determin...
# 48    [Mehab Qureshi]  Coinbase COIN on Tuesday launched #Crypto435, ...
#
#                                          banner_image          source  \
# 11  https://cdn.benzinga.com/files/images/story/20...        Benzinga
# 20                                               None  Investor Ideas
# 23        https://images.barrons.com/im-324835/social         Barrons
# 47  https://g.foolcdn.com/image/?url=https%3A%2F%2...     Motley Fool
# 48  https://cdn.benzinga.com/files/images/story/20...        Benzinga
#
#    category_within_source          source_domain  \
# 11                Markets       www.benzinga.com
# 20                    n/a  www.investorideas.com
# 23                    n/a        www.barrons.com
# 47                    n/a           www.fool.com
# 48                Markets       www.benzinga.com
#
#                                                topics  \
# 11  [{'topic': 'Finance', 'relevance_score': '0.5'...
# 20  [{'topic': 'Life Sciences', 'relevance_score':...
# 23  [{'topic': 'Finance', 'relevance_score': '1.0'...
# 47  [{'topic': 'Economy - Monetary', 'relevance_sc...
# 48  [{'topic': 'Finance', 'relevance_score': '1.0'...
#
#     overall_sentiment_score overall_sentiment_label  \
# 11                 0.213459        Somewhat-Bullish
# 20                 0.268336        Somewhat-Bullish
# 23                 0.298702        Somewhat-Bullish
# 47                 0.236590        Somewhat-Bullish
# 48                 0.257247        Somewhat-Bullish
#
#                                      ticker_sentiment
# 11  [{'ticker': 'COIN', 'relevance_score': '0.1554...
# 20  [{'ticker': 'GOOG', 'relevance_score': '0.0557...
# 23  [{'ticker': 'COIN', 'relevance_score': '0.9135...
# 47  [{'ticker': 'BLK', 'relevance_score': '0.16655...
# 48  [{'ticker': 'COIN', 'relevance_score': '0.5671...
