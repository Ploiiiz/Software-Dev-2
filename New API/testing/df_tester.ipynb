# %%
import realtest
import credentials
import av_caller
import db
import transformer
import main

# %%
key = credentials.av_api_key
symbol = 'MSFT'

# %%
data = main.load_data(symbol,interval='daily')[:180]
data
# Out:
#                timestamp     open      high     low   close  adjusted_close  \
# 0    2023-03-06 00:00:00  256.425  260.1200  255.98  256.87      256.870000
# 1    2023-03-03 00:00:00  252.190  255.6200  251.39  255.29      255.290000
# 2    2023-03-02 00:00:00  246.550  251.4000  245.61  251.11      251.110000
# 3    2023-03-01 00:00:00  250.760  250.9300  245.79  246.27      246.270000
# 4    2023-02-28 00:00:00  249.070  251.4900  248.73  249.42      249.420000
# ..                   ...      ...       ...     ...     ...             ...
# 175  2022-06-23 00:00:00  255.570  259.3700  253.63  258.86      256.936916
# 176  2022-06-22 00:00:00  251.890  257.1700  250.37  253.13      251.249484
# 177  2022-06-21 00:00:00  250.255  254.7500  249.51  253.74      251.854952
# 178  2022-06-17 00:00:00  244.700  250.5000  244.03  247.65      245.810195
# 179  2022-06-16 00:00:00  245.980  247.4174  243.02  244.97      243.150105
#
#        volume  dividend_amount
# ...

# %%
import plotly.graph_objects as go

from datetime import datetime

# %%
data1 = main.load_data(symbol,interval='weekly')[:150]
data2 = main.load_data(symbol,interval='monthly')[:120]
# data3 = main.load_data(symbol,interval='monthly')

# %%
layout = go.Layout(
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,42,61,1)',
)
fig = go.Figure(data=[go.Candlestick(x=data['timestamp'],
                open=data['open'],
                high=data['high'],
                low=data['low'],
                close=data['close'])],
                layout=layout)
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.update_layout(
    updatemenus=[
        dict(
            type = "buttons",
            direction = "left",
            buttons=[
            {'label': '1D',
             'method': 'update',
             'args': [{'x': [data['timestamp']],
                       'open': [data['open']],
                       'high': [data['high']],
                       'low': [data['low']],
                       'close': [data['close']]}]},
            {'label': '1W',
             'method': 'update',
             'args': [{'x': [data1['timestamp']],
                       'open': [data1['open']],
                       'high': [data1['high']],
                       'low': [data1['low']],
                       'close': [data1['close']]}]},
            {'label': '1M',
             'method': 'update',
             'args': [{'x': [data2['timestamp']],
                       'open': [data2['open']],
                       'high': [data2['high']],
                       'low': [data2['low']],
                       'close': [data2['close']]}]},           
        ],
            pad={"r": 10, "t": 10},
            showactive=True,
            x=0.04,
            xanchor="left",
            y=1.3,
            yanchor="top"
        ),
    ]
)
fig.show()
