# %%
import pandas
from av_getdata import *
from pprint import pprint
import sys

# %%
news = NewsSentiment()
items,info = news.news()

# %%
news.filter_sentiments(info,'Somewhat-Bullish')

# %%
tech = StocksData()
em,meta = tech.ema('IBM','daily',20,'close')

# %%
em
# Out:
#                  EMA
# date
# 1999-11-29   53.9181
# 1999-11-30   54.1983
# 1999-12-01   54.4707
# 1999-12-02   54.8143
# 1999-12-03   55.4720
# ...              ...
# 2023-01-09  142.7906
# 2023-01-10  142.9819
# 2023-01-11  143.1989
# 2023-01-12  143.4228
# 2023-01-13  143.6578
#
# [5820 rows x 1 columns]

# %%
fd,meta = tech.quarterly_balance_sheet('IBM')

# %%
fd

# %%
data = StocksData()
ibm,meta = data.daily_adjusted('IBM','full')

# %%
from plotting import Plotter
plotter = Plotter(ibm)
fig = plotter.timeseries_fig()

# %%
fig.show()

# %%
ibm.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. adjusted close',
#        '6. volume', '7. dividend amount', '8. split coefficient'],
#       dtype='object')

# %%
ibm_mon,meta = data.monthly_adjusted('IBM')

# %%
ibm_mon.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. adjusted close',
#        '6. volume', '7. dividend amount'],
#       dtype='object')

# %%
ibm.head(1)
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2023-01-13   144.06    146.1  144.01    145.89             145.89  2455786.0
#
#             7. dividend amount  8. split coefficient
# date
# 2023-01-13                 0.0                   1.0

# %%
ibm['1. open']
# Out:
# date
# 2023-01-13    144.06
# 2023-01-12    144.88
# 2023-01-11    145.00
# 2023-01-10    143.61
# 2023-01-09    144.08
#                ...
# 1999-11-05     92.75
# 1999-11-04     94.44
# 1999-11-03     95.87
# 1999-11-02     96.75
# 1999-11-01     98.50
# Name: 1. open, Length: 5839, dtype: float64
