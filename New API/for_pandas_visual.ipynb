# %%
import pandas
from av_getdata import *
from pprint import pprint
import sys

# %%
news = NewsSentiment()
items,info = news.news()

# %%
news.filter_sentiments(info,'Somewhat-Bullish')
# Out:
#                                                 title  \
# 1   City Union Bank shares crash 13.5% after Q3 ea...
# 2   Vitalik Buterin donates $227k to help earthqua...
# 4   Chiefs receiver finds out on live TV that the ...
# 9   Pinduoduo's US shopping app takes on Shein wit...
# 13  Abu Dhabi's ADNOC Drilling net profit rises 33...
# 18  The all-encompassing Amrit Kaal Union Budget -...
# 27  Kansas City Chiefs Free Agent JuJu Smith-Schus...
# 33  Coforge slides 7% as over 7 million equity sha...
# 38  Glenmark Pharma jumps 5% post December quarter...
# 43  Legendary Apple Designer Jony Ive Makes Logo F...
# 45  TÜV Rheinland qualifies for audits under the I...
#
#                                                   url   time_published  \
# 1   https://www.business-standard.com/article/mark...  20230213T055400
# 2   https://cointelegraph.com/news/vitalik-buterin...  20230213T055219
# 4   https://africa.businessinsider.com/sports/chie...  20230213T053814
# ...

# %%
tech = StocksData()
em,meta = tech.ema('IBM','daily',20,'close')

# %%
em
# Out:
#                  EMA
# date
# 1999-11-29   53.9181
# 1999-11-30   54.1983
# 1999-12-01   54.4707
# 1999-12-02   54.8143
# 1999-12-03   55.4720
# ...              ...
# 2023-01-09  142.7906
# 2023-01-10  142.9819
# 2023-01-11  143.1989
# 2023-01-12  143.4228
# 2023-01-13  143.6578
#
# [5820 rows x 1 columns]

# %%
fd,meta = tech.quarterly_balance_sheet('IBM')

# %%
fd

# %%
data = StocksData()
ibm,meta = data.intraday('IBM','30min')

# %%
ibm
# Out:
#                      1. open   2. high   3. low  4. close  5. volume
# date
# 2023-01-23 20:00:00  141.860  141.8600  141.860   141.860      516.0
# 2023-01-23 18:00:00  141.800  142.0000  141.800   142.000      490.0
# 2023-01-23 17:00:00  141.860  141.8600  141.860   141.860    88538.0
# 2023-01-23 16:00:00  141.610  141.9800  141.555   141.860  1017583.0
# 2023-01-23 15:00:00  142.625  142.6825  141.480   141.595   460716.0
# ...                      ...       ...      ...       ...        ...
# 2022-11-28 12:00:00  147.350  147.7000  147.320   147.645   291217.0
# 2022-11-28 11:00:00  147.480  147.7800  147.280   147.320   381681.0
# 2022-11-28 10:00:00  147.280  148.2400  147.280   147.480   355922.0
# 2022-11-28 09:00:00  147.740  147.7400  147.500   147.590     1880.0
# 2022-11-28 08:00:00  147.610  147.9000  147.610   147.900      907.0
#
# [426 rows x 5 columns]

# %%
from plotting import Plotter
plotter = Plotter(ibm)
fig = plotter.timeseries_fig()

# %%
fig.show()

# %%
ibm.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. adjusted close',
#        '6. volume', '7. dividend amount'],
#       dtype='object')

# %%
ibm_mon,meta = data.monthly_adjusted('IBM')

# %%
ibm_mon.columns
# Out:
# Index(['1. open', '2. high', '3. low', '4. close', '5. adjusted close',
#        '6. volume', '7. dividend amount'],
#       dtype='object')

# %%
i = ibm.head(7)
print(type(i))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
for date,row in zip(i.index,i.values):
    print(date,row)
# Out:
# 2023-01-13 00:00:00 [1.440600e+02 1.461000e+02 1.440100e+02 1.458900e+02 1.458900e+02
#  2.455786e+06 0.000000e+00 1.000000e+00]
# 2023-01-12 00:00:00 [1.448800e+02 1.466600e+02 1.445200e+02 1.455500e+02 1.455500e+02
#  2.716118e+06 0.000000e+00 1.000000e+00]
# 2023-01-11 00:00:00 [1.450000e+02 1.455300e+02 1.434500e+02 1.452600e+02 1.452600e+02
#  3.268738e+06 0.000000e+00 1.000000e+00]
# 2023-01-10 00:00:00 [1.436100e+02 1.448500e+02 1.429000e+02 1.448000e+02 1.448000e+02
#  2.152172e+06 0.000000e+00 1.000000e+00]
# 2023-01-09 00:00:00 [1.440800e+02 1.454700e+02 1.434000e+02 1.435500e+02 1.435500e+02
#  3.987782e+06 0.000000e+00 1.000000e+00]
# 2023-01-06 00:00:00 [1.423800e+02 1.442500e+02 1.415800e+02 1.437000e+02 1.437000e+02
#  3.574042e+06 0.000000e+00 1.000000e+00]
# 2023-01-05 00:00:00 [1.424400e+02 1.424980e+02 1.400100e+02 1.411100e+02 1.411100e+02
#  2.866648e+06 0.000000e+00 1.000000e+00]

# %%
i
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close  6. volume  \
# date
# 2023-01-13   144.06  146.100  144.01    145.89             145.89  2455786.0
# 2023-01-12   144.88  146.660  144.52    145.55             145.55  2716118.0
# 2023-01-11   145.00  145.530  143.45    145.26             145.26  3268738.0
# 2023-01-10   143.61  144.850  142.90    144.80             144.80  2152172.0
# 2023-01-09   144.08  145.470  143.40    143.55             143.55  3987782.0
# 2023-01-06   142.38  144.250  141.58    143.70             143.70  3574042.0
# 2023-01-05   142.44  142.498  140.01    141.11             141.11  2866648.0
#
#             7. dividend amount  8. split coefficient
# date
# 2023-01-13                 0.0                   1.0
# 2023-01-12                 0.0                   1.0
# 2023-01-11                 0.0                   1.0
# 2023-01-10                 0.0                   1.0
# 2023-01-09                 0.0                   1.0
# ...
